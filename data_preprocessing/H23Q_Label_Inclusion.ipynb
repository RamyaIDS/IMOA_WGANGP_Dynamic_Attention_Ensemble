# %%
import pandas as pd
import numpy as np
import os

#Att1
os.chdir(r'D:\1-http-flood')
new = pd.read_csv("pcap1-litespeed.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 240) & (new['frame.time_relative'] < 300)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['udp.dstport'].notnull())), "Label"] = "http-flood"
print("pcap1-litespeed")
print(np.sum(new["Label"] == "http-flood"))
new.to_csv("pcap1-litespeed-l.csv",index=False)

new = pd.read_csv("pcap1-caddy.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 300) & (new['frame.time_relative'] < 360)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['udp.dstport'].notnull())), "Label"] = "http-flood"
print("pcap1-caddy")
print(np.sum(new["Label"] == "http-flood"))
new.to_csv("pcap1-caddy-l.csv",index=False)

new = pd.read_csv("pcap1-nginx.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 360) & (new['frame.time_relative'] < 420)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['udp.dstport'].notnull())), "Label"] = "http-flood"
print("pcap1-nginx")
print(np.sum(new["Label"] == "http-flood"))
new.to_csv("pcap1-nginx-l.csv",index=False)

new = pd.read_csv("pcap1-windows.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 420) & (new['frame.time_relative'] < 480)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['udp.dstport'].notnull())), "Label"] = "http-flood"
print("pcap1-windows")
print(np.sum(new["Label"] == "http-flood"))
new.to_csv("pcap1-windows-l.csv",index=False)

new = pd.read_csv("pcap1-cloudflare.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 480) & (new['frame.time_relative'] < 540)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['udp.dstport'].notnull())), "Label"] = "http-flood"
print("pcap1-cloudflare")
print(np.sum(new["Label"] == "http-flood"))
new.to_csv("pcap1-cloudflare-l.csv",index=False)

new = pd.read_csv("pcap1-h2o.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 540) & (new['frame.time_relative'] < 600)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['udp.dstport'].notnull())), "Label"] = "http-flood"
print("pcap1-h2o")
print(np.sum(new["Label"] == "http-flood"))
new.to_csv("pcap1-h2o-l.csv",index=False)
# Out:
# pcap1-litespeed
# 112466
# pcap1-caddy
# 64082
# pcap1-nginx
# 71588
# pcap1-windows
# 87720
# pcap1-cloudflare
# 76747
# pcap1-h2o
# 86207

# %%
#Att2
os.chdir(r'D:\2-fuzzing')
new = pd.read_csv("pcap2-litespeed.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 240) & (new['frame.time_relative'] < 300)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['quic.packet_length'].isnull())), "Label"] = "fuzzing"
print("pcap2-litespeed")
print(np.sum(new["Label"] == "fuzzing"))
new.to_csv("pcap2-litespeed-l.csv",index=False) 

new = pd.read_csv("pcap2-caddy.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 300) & (new['frame.time_relative'] < 360)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['quic.packet_length'].isnull())), "Label"] = "fuzzing"
print("pcap2-caddy")
print(np.sum(new["Label"] == "fuzzing"))
new.to_csv("pcap2-caddy-l.csv",index=False) 

new = pd.read_csv("pcap2-nginx.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 360) & (new['frame.time_relative'] < 420)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['quic.packet_length'].isnull())), "Label"] = "fuzzing"
print("pcap2-nginx")
print(np.sum(new["Label"] == "fuzzing"))
new.to_csv("pcap2-nginx-l.csv",index=False) 

new = pd.read_csv("pcap2-windows.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 420) & (new['frame.time_relative'] < 480)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['quic.packet_length'].isnull())), "Label"] = "fuzzing"
print("pcap2-windows")
print(np.sum(new["Label"] == "fuzzing"))
new.to_csv("pcap2-windows-l.csv",index=False) 

new = pd.read_csv("pcap2-cloudflare.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 480) & (new['frame.time_relative'] < 540)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['quic.packet_length'].isnull())), "Label"] = "fuzzing"
print("pcap2-cloudflare")
print(np.sum(new["Label"] == "fuzzing"))
new.to_csv("pcap2-cloudflare-l.csv",index=False) 

new = pd.read_csv("pcap2-h2o.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 540) & (new['frame.time_relative'] < 600)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['quic.packet_length'].isnull())), "Label"] = "fuzzing"
print("pcap2-h2o")
print(np.sum(new["Label"] == "fuzzing"))
new.to_csv("pcap2-h2o-l.csv",index=False)
# Out:
# pcap2-litespeed
# 2440
# pcap2-caddy
# 3085
# pcap2-nginx
# 3175
# pcap2-windows
# 6799
# pcap2-cloudflare
# 2552
# pcap2-h2o
# 4173

# %%
#Att3
os.chdir(r'D:\3-http-loris')
new = pd.read_csv("pcap3-litespeed.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 240) & (new['frame.time_relative'] < 320)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194") | (new['ip.src'] == "5.203.228.219") | (new['ip.dst'] == "5.203.228.219")) & (new['udp.dstport'].notnull())), "Label"] = "http-loris"
print("pcap3-litespeed")
print(np.sum(new["Label"] == "http-loris"))
new.to_csv("pcap3-litespeed-l.csv",index=False) 

new = pd.read_csv("pcap3-caddy.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 300) & (new['frame.time_relative'] < 380)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194") | (new['ip.src'] == "5.203.228.219") | (new['ip.dst'] == "5.203.228.219")) & (new['udp.dstport'].notnull())), "Label"] = "http-loris"
print("pcap3-caddy")
print(np.sum(new["Label"] == "http-loris"))
new.to_csv("pcap3-caddy-l.csv",index=False) 

new = pd.read_csv("pcap3-nginx.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 360) & (new['frame.time_relative'] < 440)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194") | (new['ip.src'] == "5.203.228.219") | (new['ip.dst'] == "5.203.228.219")) & (new['udp.dstport'].notnull())), "Label"] = "http-loris"
print("pcap3-nginx")
print(np.sum(new["Label"] == "http-loris"))
new.to_csv("pcap3-nginx-l.csv",index=False) 

new = pd.read_csv("pcap3-windows.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 420) & (new['frame.time_relative'] < 500)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194") | (new['ip.src'] == "5.203.228.219") | (new['ip.dst'] == "5.203.228.219")) & (new['udp.dstport'].notnull())), "Label"] = "http-loris"
print("pcap3-windows")
print(np.sum(new["Label"] == "http-loris"))
new.to_csv("pcap3-windows-l.csv",index=False) 

new = pd.read_csv("pcap3-cloudflare.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 480) & (new['frame.time_relative'] < 560)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194") | (new['ip.src'] == "5.203.228.219") | (new['ip.dst'] == "5.203.228.219")) & (new['udp.dstport'].notnull())), "Label"] = "http-loris"
print("pcap3-cloudflare")
print(np.sum(new["Label"] == "http-loris"))
new.to_csv("pcap3-cloudflare-l.csv",index=False) 

new = pd.read_csv("pcap3-h2o.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 540) & (new['frame.time_relative'] < 620)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194") | (new['ip.src'] == "5.203.228.219") | (new['ip.dst'] == "5.203.228.219")) & (new['udp.dstport'].notnull())), "Label"] = "http-loris"
print("pcap3-h2o")
print(np.sum(new["Label"] == "http-loris"))
new.to_csv("pcap3-h2o-l.csv",index=False)
# Out:
# pcap3-litespeed
# 24060
# pcap3-caddy
# 14579
# pcap3-nginx
# 7210
# pcap3-windows
# 9566
# pcap3-cloudflare
# 15713
# pcap3-h2o
# 3444

# %%
#Att4
os.chdir(r'D:\4-http-stream')
new = pd.read_csv("pcap4-litespeed.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 240) & (new['frame.time_relative'] < 300) | ((new['frame.time_relative'] > 780) & (new['frame.time_relative'] > 840))) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & ((new['http3.settings.qpack.max_table_capacity'] == 409600) | (new['http3.settings.qpack.max_table_capacity'] == 16))), "Label"] = "http-stream"
print("pcap4-litespeed")
print(np.sum(new["Label"] == "http-stream"))
new.to_csv("pcap4-litespeed-l.csv",index=False) 

new = pd.read_csv("pcap4-caddy.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 300) & (new['frame.time_relative'] < 360) | ((new['frame.time_relative'] > 840) & (new['frame.time_relative'] > 900))) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & ((new['http3.settings.qpack.max_table_capacity'] == 409600) | (new['http3.settings.qpack.max_table_capacity'] == 16))), "Label"] = "http-stream"
print("pcap4-caddy")
print(np.sum(new["Label"] == "http-stream"))
new.to_csv("pcap4-caddy-l.csv",index=False)

new = pd.read_csv("pcap4-nginx.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 360) & (new['frame.time_relative'] < 420) | ((new['frame.time_relative'] > 900) & (new['frame.time_relative'] > 960))) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & ((new['http3.settings.qpack.max_table_capacity'] == 409600) | (new['http3.settings.qpack.max_table_capacity'] == 16))), "Label"] = "http-stream"
print("pcap4-nginx")
print(np.sum(new["Label"] == "http-stream"))
new.to_csv("pcap4-nginx-l.csv",index=False)

new = pd.read_csv("pcap4-windows.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 420) & (new['frame.time_relative'] < 480) | ((new['frame.time_relative'] > 960) & (new['frame.time_relative'] > 1020))) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & ((new['http3.settings.qpack.max_table_capacity'] == 409600) | (new['http3.settings.qpack.max_table_capacity'] == 16))), "Label"] = "http-stream"
print("pcap4-windows")
print(np.sum(new["Label"] == "http-stream"))
new.to_csv("pcap4-windows-l.csv",index=False)

new = pd.read_csv("pcap4-cloudflare.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 480) & (new['frame.time_relative'] < 540) | ((new['frame.time_relative'] > 1020) & (new['frame.time_relative'] > 1080))) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & ((new['http3.settings.qpack.max_table_capacity'] == 409600) | (new['http3.settings.qpack.max_table_capacity'] == 16))), "Label"] = "http-stream"
print("pcap4-cloudflare")
print(np.sum(new["Label"] == "http-stream"))
new.to_csv("pcap4-cloudflare-l.csv",index=False)

new = pd.read_csv("pcap4-h2o.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 540) & (new['frame.time_relative'] < 600) | ((new['frame.time_relative'] > 1080) & (new['frame.time_relative'] > 1140))) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & ((new['http3.settings.qpack.max_table_capacity'] == 409600) | (new['http3.settings.qpack.max_table_capacity'] == 16))), "Label"] = "http-stream"
print("pcap4-h2o")
print(np.sum(new["Label"] == "http-stream"))
new.to_csv("pcap4-h2o-l.csv",index=False)
# Out:
# pcap4-litespeed
# 0
# pcap4-caddy
# 0
# pcap4-nginx
# 0
# pcap4-windows
# 0
# pcap4-cloudflare
# 0
# pcap4-h2o
# 0

# %%
#Att5
os.chdir(r'D:\5-quic-flood')
new = pd.read_csv("pcap5-litespeed.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 240) & (new['frame.time_relative'] < 300)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['udp.dstport'].notnull())), "Label"] = "quic-flood"
print("pcap5-litespeed")
print(np.sum(new["Label"] == "quic-flood"))
new.to_csv("pcap5-litespeed-l.csv",index=False)

new = pd.read_csv("pcap5-caddy.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 300) & (new['frame.time_relative'] < 360)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['udp.dstport'].notnull())), "Label"] = "quic-flood"
print("pcap5-caddy")
print(np.sum(new["Label"] == "quic-flood"))
new.to_csv("pcap5-caddy-l.csv",index=False)

new = pd.read_csv("pcap5-nginx.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 360) & (new['frame.time_relative'] < 420)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['udp.dstport'].notnull())), "Label"] = "quic-flood"
print("pcap5-nginx")
print(np.sum(new["Label"] == "quic-flood"))
new.to_csv("pcap5-nginx-l.csv",index=False)

new = pd.read_csv("pcap5-windows.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 420) & (new['frame.time_relative'] < 480)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['udp.dstport'].notnull())), "Label"] = "quic-flood"
print("pcap5-windows")
print(np.sum(new["Label"] == "quic-flood"))
new.to_csv("pcap5-windows-l.csv",index=False)

new = pd.read_csv("pcap5-cloudflare.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 480) & (new['frame.time_relative'] < 540)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['udp.dstport'].notnull())), "Label"] = "quic-flood"
print("pcap5-cloudflare")
print(np.sum(new["Label"] == "quic-flood"))
new.to_csv("pcap5-cloudflare-l.csv",index=False)

new = pd.read_csv("pcap5-h2o.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 540) & (new['frame.time_relative'] < 600)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['udp.dstport'].notnull())), "Label"] = "quic-flood"
print("pcap5-h2o")
print(np.sum(new["Label"] == "quic-flood"))
new.to_csv("pcap5-h2o-l.csv",index=False)
# Out:
# pcap5-litespeed
# 8215
# pcap5-caddy
# 7798
# pcap5-nginx
# 8345
# pcap5-windows
# 23210
# pcap5-cloudflare
# 6550
# pcap5-h2o
# 7222

# %%
#Att6
os.chdir(r'D:\6-quic-loris')
new = pd.read_csv("pcap6-litespeed.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 240) & (new['frame.time_relative'] < 320)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194") | (new['ip.src'] == "5.203.228.219") | (new['ip.dst'] == "5.203.228.219")) & (new['udp.dstport'].notnull())), "Label"] = "quic-loris"
print("pcap6-litespeed")
print(np.sum(new["Label"] == "quic-loris"))
new.to_csv("pcap6-litespeed-l.csv",index=False) 

new = pd.read_csv("pcap6-caddy.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 300) & (new['frame.time_relative'] < 380)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194") | (new['ip.src'] == "5.203.228.219") | (new['ip.dst'] == "5.203.228.219")) & (new['udp.dstport'].notnull())), "Label"] = "quic-loris"
print("pcap6-caddy")
print(np.sum(new["Label"] == "quic-loris"))
new.to_csv("pcap6-caddy-l.csv",index=False) 

new = pd.read_csv("pcap6-nginx.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 360) & (new['frame.time_relative'] < 440)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194") | (new['ip.src'] == "5.203.228.219") | (new['ip.dst'] == "5.203.228.219")) & (new['udp.dstport'].notnull())), "Label"] = "quic-loris"
print("pcap6-nginx")
print(np.sum(new["Label"] == "quic-loris"))
new.to_csv("pcap6-nginx-l.csv",index=False) 

new = pd.read_csv("pcap6-windows.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 420) & (new['frame.time_relative'] < 500)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194") | (new['ip.src'] == "5.203.228.219") | (new['ip.dst'] == "5.203.228.219")) & (new['udp.dstport'].notnull())), "Label"] = "quic-loris"
print("pcap6-windows")
print(np.sum(new["Label"] == "quic-loris"))
new.to_csv("pcap6-windows-l.csv",index=False) 

new = pd.read_csv("pcap6-cloudflare.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 480) & (new['frame.time_relative'] < 560)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194") | (new['ip.src'] == "5.203.228.219") | (new['ip.dst'] == "5.203.228.219")) & (new['udp.dstport'].notnull())), "Label"] = "quic-loris"
print("pcap6-cloudflare")
print(np.sum(new["Label"] == "quic-loris"))
new.to_csv("pcap6-cloudflare-l.csv",index=False) 

new = pd.read_csv("pcap6-h2o.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 540) & (new['frame.time_relative'] < 620)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194") | (new['ip.src'] == "5.203.228.219") | (new['ip.dst'] == "5.203.228.219")) & (new['udp.dstport'].notnull())), "Label"] = "quic-loris"
print("pcap6-h2o")
print(np.sum(new["Label"] == "quic-loris"))
new.to_csv("pcap6-h2o-l.csv",index=False)
# Out:
# pcap6-litespeed
# 15075
# pcap6-caddy
# 51
# pcap6-nginx
# 759
# pcap6-windows
# 1699
# pcap6-cloudflare
# 6632
# pcap6-h2o
# 53

# %%
#Att7
os.chdir(r'D:\7-quic-enc')
new = pd.read_csv("pcap7-litespeed.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 240) & (new['frame.time_relative'] < 300)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['dns.id'].notnull())), "Label"] = "quic-enc"
print("pcap7-litespeed")
print(np.sum(new["Label"] == "quic-enc"))
new.to_csv("pcap7-litespeed-l.csv",index=False)

new = pd.read_csv("pcap7-caddy.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 300) & (new['frame.time_relative'] < 360)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['dns.id'].notnull())), "Label"] = "quic-enc"
print("pcap7-caddy")
print(np.sum(new["Label"] == "quic-enc"))
new.to_csv("pcap7-caddy-l.csv",index=False)

new = pd.read_csv("pcap7-nginx.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 360) & (new['frame.time_relative'] < 420)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['dns.id'].notnull())), "Label"] = "quic-enc"
print("pcap7-nginx")
print(np.sum(new["Label"] == "quic-enc"))
new.to_csv("pcap7-nginx-l.csv",index=False)

new = pd.read_csv("pcap7-windows.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 420) & (new['frame.time_relative'] < 480)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['dns.id'].notnull())), "Label"] = "quic-enc"
print("pcap7-windows")
print(np.sum(new["Label"] == "quic-enc"))
new.to_csv("pcap7-windows-l.csv",index=False)

new = pd.read_csv("pcap7-cloudflare.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 480) & (new['frame.time_relative'] < 540)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['dns.id'].notnull())), "Label"] = "quic-enc"
print("pcap7-cloudflare")
print(np.sum(new["Label"] == "quic-enc"))
new.to_csv("pcap7-cloudflare-l.csv",index=False)

new = pd.read_csv("pcap7-h2o.csv",low_memory=False)
new['Label'] = "Normal" 
new.loc[((new['frame.time_relative'] > 540) & (new['frame.time_relative'] < 600)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['dns.id'].notnull())), "Label"] = "quic-enc"
print("pcap7-h2o")
print(np.sum(new["Label"] == "quic-enc"))
new.to_csv("pcap7-h2o-l.csv",index=False)
# Out:
# pcap7-litespeed
# 689
# pcap7-caddy
# 847
# pcap7-nginx
# 1300
# pcap7-windows
# 1091
# pcap7-cloudflare
# 1006
# pcap7-h2o
# 896

# %%
#Att8
os.chdir(r'D:\8-http-smuggle')
new = pd.read_csv("pcap8-litespeed.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 180) & (new['frame.time_relative'] < 300)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['urlencoded-form.key'].notnull())), "Label"] = "http-smuggle"
print("pcap8-litespeed")
print(np.sum(new["Label"] == "http-smuggle"))
new.to_csv("pcap8-litespeed-l.csv",index=False) 

new = pd.read_csv("pcap8-caddy.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 300) & (new['frame.time_relative'] < 420)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['urlencoded-form.key'].notnull())), "Label"] = "http-smuggle"
print("pcap8-caddy")
print(np.sum(new["Label"] == "http-smuggle"))
new.to_csv("pcap8-caddy-l.csv",index=False) 

new = pd.read_csv("pcap8-nginx.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 420) & (new['frame.time_relative'] < 540)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['urlencoded-form.key'].notnull())), "Label"] = "http-smuggle"
print("pcap8-nginx")
print(np.sum(new["Label"] == "http-smuggle"))
new.to_csv("pcap8-nginx-l.csv",index=False) 

new = pd.read_csv("pcap8-windows.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 540) & (new['frame.time_relative'] < 660)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['urlencoded-form.key'].notnull())), "Label"] = "http-smuggle"
print("pcap8-windows")
print(np.sum(new["Label"] == "http-smuggle"))
new.to_csv("pcap8-windows-l.csv",index=False) 

new = pd.read_csv("pcap8-cloudflare.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 660) & (new['frame.time_relative'] < 780)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['urlencoded-form.key'].notnull())), "Label"] = "http-smuggle"
print("pcap8-cloudflare")
print(np.sum(new["Label"] == "http-smuggle"))
new.to_csv("pcap8-cloudflare-l.csv",index=False) 

new = pd.read_csv("pcap8-h2o.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 780) & (new['frame.time_relative'] < 900)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['urlencoded-form.key'].notnull())), "Label"] = "http-smuggle"
print("pcap8-h2o")
print(np.sum(new["Label"] == "http-smuggle"))
new.to_csv("pcap8-h2o-l.csv",index=False)
# Out:
# pcap8-litespeed
# 749
# pcap8-caddy
# 536
# pcap8-nginx
# 342
# pcap8-windows
# 540
# pcap8-cloudflare
# 403
# pcap8-h2o
# 425

# %%
#Att9
os.chdir(r'D:\9-http2-concurrent')
new = pd.read_csv("pcap9-litespeed.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 180) & (new['frame.time_relative'] < 210)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['http.host'].notnull())), "Label"] = "http2-concurrent"
print("pcap9-litespeed")
print(np.sum(new["Label"] == "http2-concurrent"))
new.to_csv("pcap9-litespeed-l.csv",index=False) 

new = pd.read_csv("pcap9-caddy.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 210) & (new['frame.time_relative'] < 240)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['http2.length'].notnull())), "Label"] = "http2-concurrent"
print("pcap9-caddy")
print(np.sum(new["Label"] == "http2-concurrent"))
new.to_csv("pcap9-caddy-l.csv",index=False) 

new = pd.read_csv("pcap9-nginx.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 240) & (new['frame.time_relative'] < 270)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['http.host'].notnull())), "Label"] = "http2-concurrent"
print("pcap9-nginx")
print(np.sum(new["Label"] == "http2-concurrent"))
new.to_csv("pcap9-nginx-l.csv",index=False) 

new = pd.read_csv("pcap9-windows.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 270) & (new['frame.time_relative'] < 300)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['http2.length'].notnull())), "Label"] = "http2-concurrent"
print("pcap9-windows")
print(np.sum(new["Label"] == "http2-concurrent"))
new.to_csv("pcap9-windows-l.csv",index=False) 

new = pd.read_csv("pcap9-cloudflare.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 300) & (new['frame.time_relative'] < 330)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['http.host'].notnull())), "Label"] = "http2-concurrent"
print("pcap9-cloudflare")
print(np.sum(new["Label"] == "http2-concurrent"))
new.to_csv("pcap9-cloudflare-l.csv",index=False) 

new = pd.read_csv("pcap9-h2o.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 330) & (new['frame.time_relative'] < 360)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['http2.length'].notnull())), "Label"] = "http2-concurrent"
print("pcap9-h2o")
print(np.sum(new["Label"] == "http2-concurrent"))
new.to_csv("pcap9-h2o-l.csv",index=False)
# Out:
# pcap9-litespeed
# 3997
# pcap9-caddy
# 30694
# pcap9-nginx
# 3437
# pcap9-windows
# 21567
# pcap9-cloudflare
# 175
# pcap9-h2o
# 403

# %%
#Att10
os.chdir(r'D:\10-http2-pause')
new = pd.read_csv("pcap10-litespeed.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 180) & (new['frame.time_relative'] < 210)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['http.host'].notnull())), "Label"] = "http2-pause"
print("pcap10-litespeed")
print(np.sum(new["Label"] == "http2-pause"))
new.to_csv("pcap10-litespeed-l.csv",index=False) 

new = pd.read_csv("pcap10-caddy.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 210) & (new['frame.time_relative'] < 240)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['http2.length'].notnull())), "Label"] = "http2-pause"
print("pcap10-caddy")
print(np.sum(new["Label"] == "http2-pause"))
new.to_csv("pcap10-caddy-l.csv",index=False) 

new = pd.read_csv("pcap10-nginx.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 240) & (new['frame.time_relative'] < 270)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['http.host'].notnull())), "Label"] = "http2-pause"
print("pcap10-nginx")
print(np.sum(new["Label"] == "http2-pause"))
new.to_csv("pcap10-nginx-l.csv",index=False) 

new = pd.read_csv("pcap10-windows.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 270) & (new['frame.time_relative'] < 300)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['http2.length'].notnull())), "Label"] = "http2-pause"
print("pcap10-windows")
print(np.sum(new["Label"] == "http2-pause"))
new.to_csv("pcap10-windows-l.csv",index=False) 

new = pd.read_csv("pcap10-cloudflare.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 300) & (new['frame.time_relative'] < 330)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['http.host'].notnull())), "Label"] = "http2-pause"
print("pcap10-cloudflare")
print(np.sum(new["Label"] == "http2-pause"))
new.to_csv("pcap10-cloudflare-l.csv",index=False) 

new = pd.read_csv("pcap10-h2o.csv",low_memory=False)
new['Label'] = "Normal"
new.loc[((new['frame.time_relative'] > 330)) & (((new['ip.src'] == "85.75.109.194") | (new['ip.dst'] == "85.75.109.194")) & (new['http2.length'].notnull())), "Label"] = "http2-pause"
print("pcap10-h2o")
print(np.sum(new["Label"] == "http2-pause"))
new.to_csv("pcap10-h2o-l.csv",index=False)
# Out:
# pcap10-litespeed
# 3043
# pcap10-caddy
# 23827
# pcap10-nginx
# 2880
# pcap10-windows
# 23466
# pcap10-cloudflare
# 227
# pcap10-h2o
# 106
